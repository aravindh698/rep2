# %% [markdown]
# <a href="https://colab.research.google.com/github/aravindh698/rep2/blob/master/weekim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv1=pd.read_csv('week2.csv')
csv1=csv1.dropna(0)
csv1.head()
# Out:
#    Unnamed: 0   Symbol Series  ...        vwap  Day_Perc_Change               Trends
# 1         160  M&amp;M     EQ  ...  752.028376         0.011079  Slight or no change
# 2         161  M&amp;M     EQ  ...  753.230872         0.002656  Slight or no change
# 3         162  M&amp;M     EQ  ...  753.583992         0.001457  Slight or no change
# 4         163  M&amp;M     EQ  ...  753.964804         0.000463  Slight or no change
# 5         164  M&amp;M     EQ  ...  754.814317         0.004694  Slight or no change
#
# [5 rows x 21 columns]

# %%
csv1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 493 entries, 1 to 493
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              493 non-null    int64
#  1   Symbol                  493 non-null    object
#  2   Series                  493 non-null    object
#  3   Date                    493 non-null    object
#  4   Prev Close              493 non-null    float64
#  5   Open Price              493 non-null    float64
#  6   High Price              493 non-null    float64
#  7   Low Price               493 non-null    float64
#  8   Last Price              493 non-null    float64
#  9   Close Price             493 non-null    float64
#  10  Average Price           493 non-null    float64
#  11  Total Traded Quantity   493 non-null    int64
#  12  Turnover                493 non-null    float64
#  13  No. of Trades           493 non-null    int64
# ...

# %%
csv1['Date'] =  pd.to_datetime(csv1['Date'], infer_datetime_format=True)
csv1.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0   Symbol  ... Day_Perc_Change               Trends
# 1           160  M&amp;M  ...        0.011079  Slight or no change
# 2           161  M&amp;M  ...        0.002656  Slight or no change
# 3           162  M&amp;M  ...        0.001457  Slight or no change
# 4           163  M&amp;M  ...        0.000463  Slight or no change
# 5           164  M&amp;M  ...        0.004694  Slight or no change
# ..          ...      ...  ...             ...                  ...
# 489         400  M&amp;M  ...        0.009601  Slight or no change
# 490         401  M&amp;M  ...       -0.001205  Slight or no change
# 491         402  M&amp;M  ...        0.010093  Slight or no change
# 492         403  M&amp;M  ...        0.009929  Slight or no change
# 493         404  M&amp;M  ...        0.000373  Slight or no change
#
# [493 rows x 21 columns]>

# %%
csv1.set_index('Date',inplace=True)
csv1['Close Price'].plot(figsize=(16,12))

# %%
plt.figure(figsize=(12,6))

plt.stem(csv1['year'],
         csv1['Day_Perc_Change'],
         markerfmt = 'b_',
         linefmt = 'r--',
         basefmt = 'g:'
)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   import sys

# %%
csv1['vwap'].plot(figsize=(12,6))

# %%
csv1['% Dly Qt to Traded Qty'].plot.hist()

# %%
csv1.groupby('Trends')['Total Traded Quantity'].mean().plot.bar()

# %%
csv1.groupby('Trends')['Total Traded Quantity'].median().plot.bar()

# %%
csv1['Trends'].value_counts().plot(kind='pie',subplots=True,figsize=(8,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf5bdf32b0>],
#       dtype=object)

# %%
df1=pd.read_csv('ASHOKA.csv')
df2=pd.read_csv('BAJAJELEC.csv')
df3=pd.read_csv('CENTURYPLY.csv')
df4=pd.read_csv('IRCON.csv')
df5=pd.read_csv('LAXMIMACH.csv')
df1['Date']=pd.to_datetime(df1['Date'],infer_datetime_format=True)
df2['Date']=pd.to_datetime(df2['Date'],infer_datetime_format=True)
df3['Date']=pd.to_datetime(df3['Date'],infer_datetime_format=True)
df4['Date']=pd.to_datetime(df4['Date'],infer_datetime_format=True)
df5['Date']=pd.to_datetime(df5['Date'],infer_datetime_format=True)

# %%
df5.dropna()
# Out:
#         Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0    LAXMIMACH     EQ  ...            2447                   57.24
# 1    LAXMIMACH     EQ  ...            2961                   66.29
# 2    LAXMIMACH     EQ  ...            2876                   45.51
# 3    LAXMIMACH     EQ  ...            2776                   61.69
# 4    LAXMIMACH     EQ  ...            1944                   46.40
# ..         ...    ...  ...             ...                     ...
# 489  LAXMIMACH     EQ  ...            1778                   75.02
# 490  LAXMIMACH     EQ  ...            1797                   78.92
# 491  LAXMIMACH     EQ  ...            1086                   74.33
# 492  LAXMIMACH     EQ  ...            1396                   64.93
# 493  LAXMIMACH     EQ  ...            3188                   81.76
#
# [494 rows x 15 columns]

# %%
name=['ASHOKA','BAJAJELEC','CENTURYPLY','IRCON','LAXMIMACH']
close_price=[df1['Close Price'],df2['Close Price'],df3['Close Price'],df4['Close Price'],df5['Close Price']]
list_of_tuples=zip(name,close_price)
df6=pd.DataFrame(list_of_tuples,columns=['name','close_price'])
df6.head()
# Out:
#          name                                        close_price
# 0      ASHOKA  0      216.05
# 1      214.90
# 2      217.00
# 3   ...
# 1   BAJAJELEC  0      341.15
# 1      347.00
# 2      349.85
# 3   ...
# 2  CENTURYPLY  0      266.65
# 1      266.10
# 2      264.85
# 3   ...
# 3       IRCON  0      415.30
# 1      427.00
# 2      421.40
# 3   ...
# 4   LAXMIMACH  0      4614.05
# 1      4589.80
# 2      4637.25
# 3...

# %%
df1['pdt_change']=df1['Close Price'].pct_change()
df2['pdt_change']=df2['Close Price'].pct_change()
df3['pdt_change']=df3['Close Price'].pct_change()
df4['pdt_change']=df4['Close Price'].pct_change()
df5['pdt_change']=df5['Close Price'].pct_change()
df5.head()
# Out:
#       Symbol Series  ... % Dly Qt to Traded Qty  pdt_change
# 0  LAXMIMACH     EQ  ...                  57.24         NaN
# 1  LAXMIMACH     EQ  ...                  66.29   -0.005256
# 2  LAXMIMACH     EQ  ...                  45.51    0.010338
# 3  LAXMIMACH     EQ  ...                  61.69   -0.020012
# 4  LAXMIMACH     EQ  ...                  46.40   -0.004786
#
# [5 rows x 16 columns]

# %%
df5=df5.dropna()

# %%
df4=df4.dropna()

# %%
df3=df3.dropna()

# %%
df2=df2.dropna()

# %%
df1=df1.dropna()

# %%
df8=pd.DataFrame({'ASHOKA':df1['pdt_change'],
                  'BAJAJELEC':df2['pdt_change'],
                  'CENTURYPLY':df3['pdt_change'],
                  'IRCON':df4['pdt_change'],
                  'LAXMIMACH':df5['pdt_change']})

df8.set_index(df1['Date'],inplace=True)
df8.head()
# Out:
#               ASHOKA  BAJAJELEC  CENTURYPLY     IRCON  LAXMIMACH
# Date
# 2017-05-16 -0.005323   0.017148   -0.002063  0.028172  -0.005256
# 2017-05-17  0.009772   0.008213   -0.004697 -0.013115   0.010338
# 2017-05-18 -0.033871  -0.045019   -0.016991 -0.033935  -0.020012
# 2017-05-19 -0.016218   0.006286   -0.024198 -0.017932  -0.004786
# 2017-05-22 -0.022545  -0.068263    0.005708 -0.044397  -0.013289

# %%
import seaborn as sns
sns.pairplot(df8)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df8.ASHOKA.rolling(3,win_type='triang').std().ffill(axis=0).plot()

# %%
df10=pd.read_csv('Nifty50.csv')
df10.head()
# Out:
#           Date     Open     High  ...    Close  Shares Traded  Turnover (Rs. Cr)
# 0  15-May-2017  9433.55  9449.25  ...  9445.40      145163953            7790.97
# 1  16-May-2017  9461.00  9517.20  ...  9512.25      171709433            9209.89
# 2  17-May-2017  9517.60  9532.60  ...  9525.75      211856040           10726.23
# 3  18-May-2017  9453.20  9489.10  ...  9429.45      199340647           10782.46
# 4  19-May-2017  9469.90  9505.75  ...  9427.90      259861396           11544.77
#
# [5 rows x 7 columns]

# %%
df10['voladity']=df10['Close'].pct_change().rolling(3,win_type='triang').std()*(252**0.5)
df10['voladity'].dropna()
df10['voladity'].plot()

# %%
#Set number of days and standard deviations to use for rolling lookback period for Bollinger band calculation
window = 21
no_of_std = 2

#Calculate rolling mean and standard deviation using number of days set above
rolling_mean = df10['Close'].rolling(window).mean()
rolling_std = df10['Close'].rolling(window).std()

#create two new DataFrame columns to hold values of upper and lower Bollinger bands
df10['Rolling Mean'] = rolling_mean
df10['Bollinger High'] = rolling_mean + (rolling_std * no_of_std)
df10['Bollinger Low'] = rolling_mean - (rolling_std * no_of_std)

# %%
df10[['Close','Bollinger High','Bollinger Low']].plot()
